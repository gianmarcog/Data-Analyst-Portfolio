# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
series_test = list(range(1,100))
pd.Series(series_test)
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 94    95
# 95    96
# 96    97
# 97    98
# 98    99
# Length: 99, dtype: int64

# %%
filepath = pwd + '/simple_csv.csv'
filepath
# Out:
# '/Users/gianmarcogiretti/Documents/Coding/Developer/Python_for_Data_Analyst/simple_csv.csv'

# %%
first_import = pd.read_csv(filepath, nrows=10)
first_import
# Out:
#     Column1   Column2   Column3
# 0  0.280925  0.910368  0.692982
# 1  0.719882  0.210024  0.761276
# 2  0.235752  0.059796  0.154667
# 3  0.603366  0.485614  0.013345
# 4  0.039985  0.236359  0.811832
# 5  0.015478  0.543641  0.112719
# 6  0.192540  0.409874  0.875082
# 7  0.380921  0.045468  0.515859
# 8  0.592471  0.786421  0.047249
# 9  0.072112  0.695694  0.409573

# %%
first_import["Column1"]
# Out:
# 0    0.280925
# 1    0.719882
# 2    0.235752
# 3    0.603366
# 4    0.039985
# 5    0.015478
# 6    0.192540
# 7    0.380921
# 8    0.592471
# 9    0.072112
# Name: Column1, dtype: float64

# %%
first_import["New_Column"] = 1
first_import["New_column 2"] = list(range(10))
first_import["Added Output"] = first_import["New_Column"] + first_import["New_column 2"]
first_import
# Out:
#     Column1   Column2   Column3  New_Column  New_column 2  Added Output
# 0  0.280925  0.910368  0.692982           1             0             1
# 1  0.719882  0.210024  0.761276           1             1             2
# 2  0.235752  0.059796  0.154667           1             2             3
# 3  0.603366  0.485614  0.013345           1             3             4
# 4  0.039985  0.236359  0.811832           1             4             5
# 5  0.015478  0.543641  0.112719           1             5             6
# 6  0.192540  0.409874  0.875082           1             6             7
# 7  0.380921  0.045468  0.515859           1             7             8
# 8  0.592471  0.786421  0.047249           1             8             9
# 9  0.072112  0.695694  0.409573           1             9            10

# %%
first_import = first_import.drop(columns="New_Column")

# %%
first_import.drop(columns="New_column 2", inplace=True)
first_import
# Out:
#     Column1   Column2   Column3  Added Output
# 0  0.280925  0.910368  0.692982             1
# 1  0.719882  0.210024  0.761276             2
# 2  0.235752  0.059796  0.154667             3
# 3  0.603366  0.485614  0.013345             4
# 4  0.039985  0.236359  0.811832             5
# 5  0.015478  0.543641  0.112719             6
# 6  0.192540  0.409874  0.875082             7
# 7  0.380921  0.045468  0.515859             8
# 8  0.592471  0.786421  0.047249             9
# 9  0.072112  0.695694  0.409573            10

# %%
first_import.loc[:5,["Column1","Column2","Column3","Added Output"]] #loc will include the last instance you specify
# Out:
#     Column1   Column2   Column3  Added Output
# 0  0.280925  0.910368  0.692982             1
# 1  0.719882  0.210024  0.761276             2
# 2  0.235752  0.059796  0.154667             3
# 3  0.603366  0.485614  0.013345             4
# 4  0.039985  0.236359  0.811832             5
# 5  0.015478  0.543641  0.112719             6

# %%
first_import.iloc[:6, [0,2]]
# Out:
#     Column1   Column3
# 0  0.280925  0.692982
# 1  0.719882  0.761276
# 2  0.235752  0.154667
# 3  0.603366  0.013345
# 4  0.039985  0.811832
# 5  0.015478  0.112719

# %%
netflix = pd.read_csv(pwd + "/netflix_titles.csv")
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
list(netflix.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
netflix.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
netflix["type"].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
netflix[netflix["country"] == "Germany"]
# Out:
#      show_id     type                         title                 director  \
# 102     s103    Movie           3 Türken & ein Baby              Sinan Akkuş
# 185     s186    Movie                 A Heavy Heart            Thomas Stuber
# 213     s214  TV Show               A Perfect Crime                      NaN
# 424     s425    Movie                 Alles ist gut             Eva Trobisch
# 672     s673  TV Show                Babylon Berlin                      NaN
# ...      ...      ...                           ...                      ...
# 6712   s6713    Movie               The NSU-Complex  Stefan Aust, Dirk Laabs
# 6756   s6757    Movie                 The Physician           Philipp Stölzl
# 7355   s7356  TV Show                    Unorthodox                      NaN
# 7500   s7501  TV Show               We Are the Wave                      NaN
# 7501   s7502    Movie  We Are Young. We Are Strong.           Burhan Qurbani
#
# ...

# %%
netflix[(netflix["country"] == "Germany") & (netflix["rating"] == "TV-MA")]
# Out:
#      show_id     type                                    title  \
# 102     s103    Movie                      3 Türken & ein Baby
# 185     s186    Movie                            A Heavy Heart
# 424     s425    Movie                            Alles ist gut
# 672     s673  TV Show                           Babylon Berlin
# 731     s732  TV Show                               Barbarians
# 838     s839    Movie                           Berlin Calling
# 841     s842    Movie         Berlin, Berlin: Lolle on the Run
# 931     s932  TV Show                               Biohackers
# 1277   s1278  TV Show                                  Charité
# 1363   s1364    Movie                      Christmas Crossfire
# 1539   s1540  TV Show                        Criminal: Germany
# 1592   s1593    Movie                          Dancing Quietly
# 1753   s1754    Movie              Dieter Nuhr: Nuhr in Berlin
# 1797   s1798  TV Show                           Dogs of Berlin
# ...

# %%
netflix["computer_date"] = pd.to_datetime(netflix["date_added"])
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
from datetime import datetime as dt

# %%
netflix["computer_date"].fillna(dt(2020, 1, 1), inplace = True)

# %%
netflix["unix_time"] = netflix["computer_date"].astype(int)
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix[["Date Part 1", "Date Part 2"]] = netflix["date_added"].str.split(", ", expand=True)
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.rename(columns={"Date Part 2" : "Year"}, inplace=True)
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
the_adder = lambda x: x + 210101
the_adder(1000000000)
# Out:
# 1000210101

# %%
netflix["genre_count"] = netflix["listed_in"].map(lambda x: len(x.split(",")))
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_movie_by_country = netflix.groupby("country")["show_id"].count().reset_index().sort_values(by="show_id",ascending=False)
netflix_movie_by_country
# Out:
#                                country  show_id
# 549                      United States     2555
# 229                              India      923
# 462                     United Kingdom      397
# 291                              Japan      226
# 394                        South Korea      183
# ..                                 ...      ...
# 252  Indonesia, South Korea, Singapore        1
# 253          Indonesia, United Kingdom        1
# 254           Indonesia, United States        1
# 255                       Iran, France        1
# 680                           Zimbabwe        1
#
# [681 rows x 2 columns]

# %%
second_dataset = pd.read_csv(pwd + "/netflix_titles_second.csv")
second_dataset
# Out:
#     show_id     type                             title           director  \
# 0        s1  TV Show                                3%                NaN
# 1        s2    Movie                              7:19  Jorge Michel Grau
# 2        s3    Movie                             23:59       Gilbert Chan
# 3        s4    Movie                                 9        Shane Acker
# 4        s5    Movie                                21     Robert Luketic
# ..      ...      ...                               ...                ...
# 349    s350  TV Show  Ainori Love Wagon: Asian Journey                NaN
# 350    s351  TV Show          Ainsley Eats the Streets                NaN
# 351    s352    Movie                        Ainu Mosir   Takeshi Fukunaga
# 352    s353    Movie                     Airplane Mode    César Rodrigues
# 353    s354    Movie                   Aisa Yeh Jahaan     Biswajeet Bora
#
#                                                   cast               country  \
# ...

# %%
new_dataset = pd.concat([netflix, second_dataset])
new_dataset
# Out:
#     show_id     type                             title           director  \
# 0        s1  TV Show                                3%                NaN
# 1        s2    Movie                              7:19  Jorge Michel Grau
# 2        s3    Movie                             23:59       Gilbert Chan
# 3        s4    Movie                                 9        Shane Acker
# 4        s5    Movie                                21     Robert Luketic
# ..      ...      ...                               ...                ...
# 349    s350  TV Show  Ainori Love Wagon: Asian Journey                NaN
# 350    s351  TV Show          Ainsley Eats the Streets                NaN
# 351    s352    Movie                        Ainu Mosir   Takeshi Fukunaga
# 352    s353    Movie                     Airplane Mode    César Rodrigues
# 353    s354    Movie                   Aisa Yeh Jahaan     Biswajeet Bora
#
#                                                   cast               country  \
# ...

# %%
netflix_merged = pd.merge(left=new_dataset, right=netflix_movie_by_country, how="inner", left_on=["country"], right_on=["country"])
netflix_merged
# Out:
#      show_id_x     type                      title  \
# 0           s1  TV Show                         3%
# 1         s209    Movie           A new Capitalism
# 2         s219  TV Show            A Queen Is Born
# 3         s321    Movie  Afonso Padilha: Classless
# 4         s323  TV Show        Afronta! Facing It!
# ...        ...      ...                        ...
# 7618     s7727    Movie               You Carry Me
# 7619     s7751  TV Show            Yu-Gi-Oh! Arc-V
# 7620     s7760  TV Show                  Zak Storm
# 7621     s7771    Movie                    Zinzana
# 7622     s7783    Movie                       Zozo
#
#                           director  \
# 0                              NaN
# 1                              NaN
# 2                     Carla Barros
# 3     Junior Carelli, Rudge Campos
# 4                  Juliana Vicente
# ...                            ...
# 7618                    Ivona Juka
# 7619                           NaN
# ...

# %%
pivot_table = netflix.pivot_table(index="country", columns="type", values="title", aggfunc="count", fill_value=0).reset_index()
pivot_table
# Out:
# type                                            country  Movie  TV Show
# 0                                             Argentina     34       16
# 1     Argentina, Brazil, France, Poland, Germany, De...      1        0
# 2                                      Argentina, Chile      1        0
# 3                                Argentina, Chile, Peru      1        0
# 4                                     Argentina, France      1        0
# ..                                                  ...    ...      ...
# 676                                           Venezuela      1        0
# 677                                 Venezuela, Colombia      1        0
# 678                                             Vietnam      5        0
# 679                                        West Germany      1        0
# 680                                            Zimbabwe      1        0
#
# [681 rows x 3 columns]
